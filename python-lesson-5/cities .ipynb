# %%
pip install pandas
# Out:
# ...
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/61/11/1812ef6cbd7433ad240f72161ce5f84c4c450cede4db080365d371d29117/pandas-2.2.1-cp311-cp311-win_amd64.whl.metadata
#   Using cached pandas-2.2.1-cp311-cp311-win_amd64.whl.metadata (19 kB)
# ...
#   Obtaining dependency information for numpy<2,>=1.23.2 from https://files.pythonhosted.org/packages/3f/6b/5610004206cf7f8e7ad91c5a85a8c71b2f2f8051a0c0c4d5916b76d6cbb2/numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# ...
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/9c/3d/a121f284241f08268b21359bd425f7d4825cffc5ac5cd0e1b3d82ffd2b10/pytz-2024.1-py2.py3-none-any.whl.metadata
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...

# %%
import pandas as pd

# %%
data = {'name': ['a', 'c', 'b'],
        'class':  [8, 9, 10],
    'avg': [' 100', '95', '98']
     }
# Out:
# Running cells with 'c:\Users\User\AppData\Local\Programs\Python\Python311\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/User/AppData/Local/Programs/Python/Python311/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
sample = pd.DataFrame(data)
sample
# Out:
#   name  class   avg
# 0    a      8   100
# 1    c      9    95
# 2    b     10    98

# %%
sample.loc[len(sample)]={'name': 'f' , 'class': 11 , 'avg': 89}
sample
# Out:
#   name  class   avg
# 0    a      8   100
# 1    c      9    95
# 2    b     10    98
# 3    f     11    89
# 4    f     11    89

# %%
import numpy as np

# %%
s=['d' , 8 , 88 ]

# %%
sample['name']
# Out:
# 0    a
# 1    c
# 2    b
# Name: name, dtype: object

# %%
sample[sample['class'] == 8]
# Out:
#   name  class   avg
# 0    a      8   100

# %%
sample.describe()
# Out:
#           class
# count   5.00000
# mean    9.80000
# std     1.30384
# min     8.00000
# 25%     9.00000
# 50%    10.00000
# 75%    11.00000
# max    11.00000

# %%
sample.describe().tail(1)
# Out:
#      class
# max   11.0

# %%
df = pd.read_csv("cities.csv")

# %%
df
# Out:
#      LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0      41        5       59   "N"       80       39        0   "W"
# 1      42       52       48   "N"       97       23       23   "W"
# 2      46       35       59   "N"      120       30       36   "W"
# 3      42       16       12   "N"       71       48        0   "W"
# 4      43       37       48   "N"       89       46       11   "W"
# ..    ...      ...      ...   ...      ...      ...      ...   ...
# 123    39       31       12   "N"      119       48       35   "W"
# 124    50       25       11   "N"      104       39        0   "W"
# 125    40       10       48   "N"      122       14       23   "W"
# 126    40       19       48   "N"       75       55       48   "W"
# 127    41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State"
# 0          "Youngstown"       OH
# 1             "Yankton"       SD
# 2              "Yakima"       WA
# ...

# %%
df.LatD = df.LatD.fillna(0)
df.isnull().sum().sum()
# Out:
# 0

# %%
df.drop_duplicates()
# Out:
#      LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0      41        5       59   "N"       80       39        0   "W"
# 1      42       52       48   "N"       97       23       23   "W"
# 2      46       35       59   "N"      120       30       36   "W"
# 3      42       16       12   "N"       71       48        0   "W"
# 4      43       37       48   "N"       89       46       11   "W"
# ..    ...      ...      ...   ...      ...      ...      ...   ...
# 123    39       31       12   "N"      119       48       35   "W"
# 124    50       25       11   "N"      104       39        0   "W"
# 125    40       10       48   "N"      122       14       23   "W"
# 126    40       19       48   "N"       75       55       48   "W"
# 127    41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State"
# 0          "Youngstown"       OH
# 1             "Yankton"       SD
# 2              "Yakima"       WA
# ...

# %%
df.isnull().sum()
# Out:
# LatD        0
#  "LatM"     0
#  "LatS"     0
#  "NS"       0
#  "LonD"     0
#  "LonM"     0
#  "LonS"     0
#  "EW"       0
#  "City"     0
#  "State"    0
# dtype: int64

# %%
df.LatD = df.LatD.fillna(0)

# %%
df
# Out:
#      LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0      41        5       59   "N"       80       39        0   "W"
# 1      42       52       48   "N"       97       23       23   "W"
# 2      46       35       59   "N"      120       30       36   "W"
# 3      42       16       12   "N"       71       48        0   "W"
# 4      43       37       48   "N"       89       46       11   "W"
# ..    ...      ...      ...   ...      ...      ...      ...   ...
# 123    39       31       12   "N"      119       48       35   "W"
# 124    50       25       11   "N"      104       39        0   "W"
# 125    40       10       48   "N"      122       14       23   "W"
# 126    40       19       48   "N"       75       55       48   "W"
# 127    41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State"
# 0          "Youngstown"       OH
# 1             "Yankton"       SD
# 2              "Yakima"       WA
# ...

# %%
df['LatD'].mean()
# Out:
# 38.8203125

# %%
df['LatD'].min()
# Out:
# 26

# %%
df['LatD'].max()
# Out:
# 50

# %%
df.insert(1, 'is_expensive1', df['LatD']/df['LatD'])
df
# Out:
#      LatD  is_expensive1   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  \
# 0      41            1.0        5       59   "N"       80       39        0
# 1      42            1.0       52       48   "N"       97       23       23
# 2      46            1.0       35       59   "N"      120       30       36
# 3      42            1.0       16       12   "N"       71       48        0
# 4      43            1.0       37       48   "N"       89       46       11
# ..    ...            ...      ...      ...   ...      ...      ...      ...
# 123    39            1.0       31       12   "N"      119       48       35
# 124    50            1.0       25       11   "N"      104       39        0
# 125    40            1.0       10       48   "N"      122       14       23
# 126    40            1.0       19       48   "N"       75       55       48
# 127    41            1.0        9       35   "N"       81       14       23
#
#      "EW"              "City"  "State"
# ...

# %%
df.rename(columns={'is_expensive1': 'Population'}, inplace=True)
df
# Out:
#      LatD  Population   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  \
# 0      41         1.0        5       59   "N"       80       39        0
# 1      42         1.0       52       48   "N"       97       23       23
# 2      46         1.0       35       59   "N"      120       30       36
# 3      42         1.0       16       12   "N"       71       48        0
# 4      43         1.0       37       48   "N"       89       46       11
# ..    ...         ...      ...      ...   ...      ...      ...      ...
# 123    39         1.0       31       12   "N"      119       48       35
# 124    50         1.0       25       11   "N"      104       39        0
# 125    40         1.0       10       48   "N"      122       14       23
# 126    40         1.0       19       48   "N"       75       55       48
# 127    41         1.0        9       35   "N"       81       14       23
#
#      "EW"              "City"  "State"
# 0     "W"        "Youngstown"       OH
# ...

# %%
df[df['LatD'] == 40]
# Out:
#      LatD  Population   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  \
# 15     40         1.0        4       11   "N"       80       43       12
# 45     40         1.0       13       47   "N"       74       46       11
# 58     40         1.0       59       24   "N"       75       11       24
# 61     40         1.0       21       36   "N"       80       37       12
# 62     40         1.0       37       11   "N"      103       13       12
# 96     40         1.0       45       35   "N"      111       52       47
# 125    40         1.0       10       48   "N"      122       14       23
# 126    40         1.0       19       48   "N"       75       55       48
#
#      "EW"             "City"  "State"
# 15    "W"         "Wheeling"       WV
# 45    "W"          "Trenton"       NJ
# 58    "W"      "Stroudsburg"       PA
# 61    "W"     "Steubenville"       OH
# 62    "W"         "Sterling"       CO
# 96    "W"   "Salt Lake City"       UT
# 125   "W"        "Red Bluff"       CA
# ...

# %%
df.sort_values(by='LatD',ascending=True)
# Out:
#      LatD  Population   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  \
# 16     26         1.0       43       11   "N"       80        3        0
# 84     27         1.0       20       24   "N"       82       31       47
# 52     27         1.0       57        0   "N"       82       26       59
# 31     28         1.0       48       35   "N"       97        0       36
# 94     29         1.0       25       12   "N"       98       30        0
# ..    ...         ...      ...      ...   ...      ...      ...      ...
# 68     47         1.0       40       11   "N"      117       24       36
# 10     48         1.0        9        0   "N"      103       37       12
# 33     49         1.0       16       12   "N"      123        7       12
# 6      49         1.0       52       48   "N"       97        9        0
# 124    50         1.0       25       11   "N"      104       39        0
#
#      "EW"              "City"  "State"
# 16    "W"   "West Palm Beach"       FL
# ...
