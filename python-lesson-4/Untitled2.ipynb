# %%
pip install numpy
# Out:
# ...
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
temp=[30,25,12,14,5,28,14,32,30,29,28,27]

# %%
plt.plot(temp)

# %%
categories = ['Category A', 'Category B', 'Category C','Category D']
values = [23, 45, 56,100]

# %%
plt.bar(categories, values)
plt.title('Bar Graph Example')
plt.xlabel('Categories')
plt.ylabel('Values')
# Out:
# Text(0, 0.5, 'Values')

# %%
x = np.random.rand(10) # 50 ערכי x אקראיים
y = np.random.rand(10) # 50 ערכי y אקראיים
plt.scatter(x, y, alpha=0.5, cmap='viridis')
plt.xlabel('huers')
plt.ylabel('marks')
# Out:
# C:\Users\huser\AppData\Local\Temp\ipykernel_1188\289559777.py:3: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y, alpha=0.5, cmap='viridis')
# Text(0, 0.5, 'marks')

# %%
ages = [22, 45, 30, 35, 50, 41, 28, 33, 55, 65, 29, 42, 48, 31]

plt.hist(ages, bins=[20, 30, 40, 50, 60, 70], edgecolor='black')

plt.title('Age Distribution')
plt.xlabel('Ages')
plt.ylabel('Number of People')
# Out:
# Text(0, 0.5, 'Number of People')

# %%
years = range(2010, 2021)
consumption_oil = [100, 105, 110, 120, 125, 130, 135, 140, 145, 150, 155]
consumption_gas = [80, 82, 85, 88, 90, 95, 100, 105, 110, 115, 120]
consumption_renewable = [20, 25, 30, 35, 40, 45, 50, 60, 70, 80, 90]
plt.plot(consumption_oil, years, '-b', label='consumption_oil')
plt.plot(consumption_gas, years, ':r', label='consumption_gas')
plt.plot(consumption_renewable, years, '-c', label='consumption_renewable')
plt.title('Line and Scatter on the Same Graph')
plt.xlabel('years')
plt.ylabel('consumption')
plt.legend()
